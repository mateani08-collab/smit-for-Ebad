# %% [markdown]
# 1) Area of a Rectangle:
# Write a Python program to calculate the area of a rectangle. Use the formula:
# 𝐴𝒓𝒆𝒂 = 𝒍𝒆𝒏𝒈𝒕𝒉 * 𝒘𝒊𝒅𝒕𝒉

# %%
length_of_rectangle=5.5
width_of_rectangle=4.0
area=length_of_rectangle*width_of_rectangle

# %%
print(area)
# Out:
# 22.0

# %% [markdown]
# 2) Circumference of a Circle:
# Write a Python program to calculate the circumference of a circle. Use the formula:
# 𝑪𝒊𝒓𝒄𝒖𝒎𝒇𝒆𝒓𝒆𝒏𝒄𝒆 = 𝟐𝝅𝒓

# %%
radius_of_circle=7.0
𝝅=3.14
circumference=2*𝝅*radius_of_circle

# %%
print(circumference)
# Out:
# 43.96

# %% [markdown]
# 3. Simple Interest:
# Write a Python program to calculate the simple interest. Use the formula:
# 𝑺𝒊𝒎𝒑𝒍𝒆 𝑰𝒏𝒕𝒆𝒓𝒆𝒔𝒕 = 𝑷𝒓𝒊𝒏𝒄𝒊𝒑𝒂𝒍 * 𝑹𝒂𝒕𝒆 * 𝑻𝒊𝒎𝒆

# %%
principal_amount=1000
rate=0.05
time_in_year=3
simple_interest=principal_amount*rate*time_in_year

# %%
print(simple_interest)
# Out:
# 150.0

# %% [markdown]
# 4. Speed of an Object:
# Write a Python program to calculate the speed of an object. Use the formula:
# 𝑆𝒑𝒆𝒆𝒅 = 𝑫𝒊𝒔𝒕𝒂𝒏𝒄𝒆 / 𝑻𝒊𝒎𝒆

# %%
distance_in_km=140
time_in_hours=50
speed=distance_in_km/time_in_hours

# %%
type(print(speed))
# Out:
# 2.8
# NoneType

# %% [markdown]
# 5. BMI Calculator:
# Write a Python program to calculate the Body Mass Index (BMI). Use the formula:
# BMI = weight(kg)/(height)^2.

# %%
weight_in_kg=62
height_in_feet=5.8
BMI=(weight_in_kg)/(height_in_feet)**2

# %%
print(BMI)
# Out:
# 1.8430439952437574

# %% [markdown]
# 6. Force Using Newton's Second Law:
# Write a Python program to calculate the force on an object. Use the formula:
# F=ma

# %%
mass_in_Kg=86
accelration_in_ms2=8.9
F=(mass_in_Kg)*(accelration_in_ms2)

# %%
print(F)
# Out:
# 765.4

# %% [markdown]
# 7. Compound Interest:
# Write a Python program to calculate compound interest. Use the formula: A=P*(1+r/n)^n-t.

# %%
p=float(input("Emter principal amount"))
r=float(input("enter annual interest rate"))
n=float(input("enter numberof times interest is compound per year"))
t=float(input("enter time in years"))

A=p*((1+r/n) **(n-t))
# Out:
# Emter principal amount 1000
# enter annual interest rate 0.05
# enter numberof times interest is compound per year 4
# enter time in years 2

# %%
print(A)
# Out:
# 1025.15625

# %% [markdown]
# 8. Perimeter of a Triangle:
# Write a Python program to calculate the perimeter of a triangle. Use the formula:
# 𝑷𝒆𝒓𝒊𝒎𝒆𝒕𝒆𝒓 = 𝒂 + 𝒃 + 𝒄

# %%
a=10
b=20
c=10

perimeter=a+b+c

# %%
print(perimeter)
# Out:
# 40

# %% [markdown]
# 9. Volume of a Sphere:
# Write a Python program to calculate the volume of a sphere. Use the formula: Volume=(4/3)*𝝅r^3

# %%
r=8

volume=(4/3)*𝝅*(r**3)

# %%
print(volume)
# Out:
# 2143.5733333333333

# %% [markdown]
# 10. Kinetic Energy:
# Write a Python program to calculate the kinetic energy of an object. Use the formula:
# 𝑲𝑬 =(1/2)mv^2

# %%
mass_in_kg=40
velocity_in_ms =30

KE=(1/2)*mass_in_kg*velocity_in_ms**2

# %%
print(KE)
# Out:
# 18000.0

# %% [markdown]
# 11) Quadratic Equation Roots:
# Write a Python program to find the roots of a quadratic equation. Use the formula:
# X1 =-b + (sqrt(b^2-4ac)/2a ,X2 =-b - (sqrt(b^2-4ac)/2a

# %%
a=5
b=7
c=9

X1 =-b + ((b**2)-4*a*c)**0.5/2*a
X2 =-b - ((b**2)-4*a*c)**0.5/2*a

# %%
print(X1)
print(X2)
# Out:
# (-6.999999999999998+28.613807855648993j)
# (-7.000000000000002-28.613807855648993j)

# %% [markdown]
# 12. Temperature Conversion:
# Write a Python program to convert a temperature from Celsius to Fahrenheit. Use the
# formula: F=(9/5)*C+32

# %%
temp_in_C=39

F=(9/5)*temp_in_C+32

# %%
print(F)
# Out:
# 102.2

# %% [markdown]
# 13. Gravitational Force:
# Write a Python program to calculate the gravitational force between two objects. Use
# the formula
# 𝑭 = G((m1*m2)/r**2)

# %%
mass_1_in_Kg=60
mass_1_in_Kg=90
G=6.67*10**-11
r=10

F= G*((mass_1_in_Kg*mass_1_in_Kg)/r**2)

# %%
print(F)
# Out:
# 5.4027e-09

# %% [markdown]
# 14. Volume of a Cylinder:
# Write a Python program to calculate the volume of a cylinder. Use the formula:
# 𝑽𝒐𝒍𝒖𝒎𝒆 = 𝝅𝒓𝟐𝒉

# %%
r=25
h=13
𝝅=3.14

volume=𝝅*r*2*h

# %%
print(volume)
# Out:
# 2041.0

# %% [markdown]
# 15) Pressure:
# Write a Python program to calculate the pressure exerted by a force on a surface. Use
# the formula:P=F/A

# %%
F=45
A=24

P=F/A

# %%
print(P)
# Out:
# 1.875

# %% [markdown]
# 16) Electric Power:
# Write a Python program to calculate the electric power consumed. Use the formula:p=V/I

# %%
V=20
I=20

electric_power=V/I

# %%
print(electric_power)
# Out:
# 1.0

# %% [markdown]
# 17. Perimeter of a Circle (Circumference):
# Write a Python program to calculate the perimeter (circumference) of a circle. Use the
# formula:p=2𝝅r

# %%
r=85
𝝅=3.14

perimeter_circumference_of_a_circle=2*𝝅*r

# %%
print(perimeter_circumference_of_a_circle)
# Out:
# 533.8000000000001

# %% [markdown]
# 18) Future Value in Savings:
# Write a Python program to calculate the future value of an investment. Use the formula:
# 𝐹𝑉 = 𝑃𝑉(1 + 𝑟)^t

# %%
present_value=250000
annual_interest_rate_as_a_decimal=0.10
time_in_years=5

FV=present_value*(1+annual_interest_rate_as_a_decimal)**time_in_years

# %%
print(FV)
# Out:
# 402627.5000000001

# %% [markdown]
# 19. Work Done by a Force:
# Write a Python program to calculate the work done by a force. Use the formula: W=f*dcos⌀

# %%
force_in_newton=50
distance_in_meter=10
angle_in_degree=90
theta_radian=math.radians(angle_in_degree)

W=force_in_newton*distance_in_meter*math.cos(theta_radian)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[74], line 4
#       1 force_in_newton=50
#       2 distance_in_meter=10
#       3 angle_in_degree=90
# ----> 4 theta_radian=math.radians(angle_in_degree)
#       5
#       6 W=force_in_newton*distance_in_meter*math.cos(theta_radian)
#
# NameError: name 'math' is not defined

# %% [markdown]
# 20) Heat Transfer:
# Write a Python program to calculate the amount of heat transferred. Use the formula Q=mc(∆t)

# %%
mass_M=2
specific_heat_capacity_c=4184
temperature_change_in_delta_t=30

Q=mass_M*specific_heat_capacity_c*(temperature_change_in_delta_t)

# %%
print(Q)
# Out:
# 251040
